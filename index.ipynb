# %% [markdown]
# # Combining DataFrames With Pandas - Lab
#
# ## Introduction
#
# In this lab, you'll gain practice combining DataFrames through concatenation.  You'll also practice executing various types of joins to selectively combine the information stored in the tables!
#
# ## Objectives
#
# * Concatenate multiple DataFrames together into a single DataFrame
# * Understand and execute the various types of joins (inner, outer, left, and right joins)
#
#
# ## Getting Started
#
# You'll start with a quick section to gain practice with concatenating datasets using `pd.concat()`.
#
# ## Concatenating DataFrames
#
# Run the cell below to create some sample DataFrames for us to work with.

# %%
import pandas as pd
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                    index=[0, 1, 2, 3])


df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                    index=[4, 5, 6, 7])

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                    'C': ['C8', 'C9', 'C10', 'C11'], 
                    'D': ['D8', 'D9', 'D10', 'D11']},
                    index=[8, 9, 10, 11])
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %% [markdown]
# Now that you have multiple DataFrames to work with, you can execute a concatenation to join them together.
#
# In the cell below, concatenate the 3 DataFrames together using the appropriate function.

# %%
frames_list = [df1, df2, df3]
df = pd.concat(frames_list)
df
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# **_EXPECTED OUTPUT:_**
#
# <img src="images/er1.png">
#
# ## Setting Join Conditions With Concatenation
#
# You can also specify if the concatenation is an **_Outer Join_** or an **_Inner Join_**.  Next, you'll execute an inner join. Before you do, you need to create another table that contains some overlapping index values with a DataFrame that already exists.
#
# Run the cell below to create the new DataFrame.

# %%
df4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'],
                    'D': ['D2', 'D3', 'D6', 'D7'],
                    'F': ['F2', 'F3', 'F6', 'F7']},
                    index=[2, 3, 6, 7])

# %% [markdown]
# Now, in the cell below, use the `pd.concat()` method to join DataFrames 1 and 4.  However, this time, specify that the `join` is `'inner'`, and `axis=1`.

# %%
df1_and_4 = [df1, df4]

df1_and_4 = df1.join(df4, how='inner', rsuffix='meow')
df1_and_4
# Out:
#     A   B   C   D Bmeow Dmeow   F
# 2  A2  B2  C2  D2    B2    D2  F2
# 3  A3  B3  C3  D3    B3    D3  F3

# %% [markdown]
# **_EXPECTED OUTPUT:_**
#
# <img src='images/er2.png'>
#
# You'll notice that in this case, the results returned contain only the rows with indexes that exist in both tables--rows 2 and 3.  The resulting table contains the values for each column in both tables for the rows.
#
# Note that there are many, many ways that you can make full use of the `concat()` functionality in pandas to join DataFrames together--these are just a few of the most common examples pulled from the pandas documentation on the subject.  For a full view of all the ways you can use `pd.concat()`, see the [pandas documentation](http://pandas.pydata.org/pandas-docs/stable/merging.html)!
#
# ## Loading In Data
# Now, it's time to move on to working with the Hearthstone cards database.  This database contains information on cards from the popular game, [Hearthstone](https://playhearthstone.com/en-us/)! For full information on the dataset, see the  [kaggle page](https://www.kaggle.com/jeradrose/hearthstone-cards) for this dataset.
#
# This database consists of the following tables:
#
# * _cards_
# * *dust_costs*
# * _entourages_
# * _mechanics_
# * *play_requirements*
#
# Many of rows in each table--but not all--correspond to the same cards. As such, each table contains a column called `card_id` which acts as a **_Primary Key_** for each table.  You'll make use of these keys to **_join_** the different tables together into a single DataFrame.  You'll also experiment with different types of joins to help us decide exactly what information you wish to combine.
#
# Simply run the cell below to import the tables from the database as DataFrames.

# %%
cards_df = pd.read_csv('cards.csv')
dust_df = pd.read_csv('dust.csv')
entourages_df = pd.read_csv('entourages.csv')
mechanics_df = pd.read_csv('mechanics.csv')
play_requirements_df = pd.read_csv('play_requirements.csv')

# %% [markdown]
# Great.  Now, let's set the correct column, `card_id`, as the index column for each of these tables, and then display each to ensure that everything is as expected.
#
# For each of the dataframes you created in the cell above, call the `.set_index()` method and pass in `card_id`.  Also set `inplace=True`.  Then, display the head of each respective DataFrame to ensure everything worked.
#
# **_NOTE:_** Since you are performing this operation in place, running any cell a second time will result in pandas throwing an error.  If you need to run something a second time, restart the kernel using the jupyter notebook menu at the top of the page.

# %%
df_list = [cards_df, dust_df, entourages_df, mechanics_df, play_requirements_df]

# for df in df_list:
#     df.set_index('card_id', inplace=True)
dust_df
# Out:
#         card_id             action  cost
# 0     BRM_010t2    CRAFTING_NORMAL    40
# 1     BRM_010t2    CRAFTING_GOLDEN   400
# 2     BRM_010t2  DISENCHANT_NORMAL     5
# 3     BRM_010t2  DISENCHANT_GOLDEN    50
# 4        AT_132    CRAFTING_NORMAL  1600
# 5        AT_132    CRAFTING_GOLDEN  3200
# 6        AT_132  DISENCHANT_NORMAL   400
# 7        AT_132  DISENCHANT_GOLDEN  1600
# 8        OG_141    CRAFTING_NORMAL    40
# 9        OG_141    CRAFTING_GOLDEN   400
# 10       OG_141  DISENCHANT_NORMAL     5
# 11       OG_141  DISENCHANT_GOLDEN    50
# 12       AT_131    CRAFTING_NORMAL  1600
# 13       AT_131    CRAFTING_GOLDEN  3200
# 14       AT_131  DISENCHANT_NORMAL   400
# 15       AT_131  DISENCHANT_GOLDEN  1600
# 16      EX1_583    CRAFTING_NORMAL    40
# 17      EX1_583    CRAFTING_GOLDEN   400
# 18      EX1_583  DISENCHANT_NORMAL     5
# 19      EX1_583  DISENCHANT_GOLDEN    50
# 20      CFM_095    CRAFTING_NORMAL   400
# 21      CFM_095    CRAFTING_GOLDEN  1600
# 22      CFM_095  DISENCHANT_NORMAL   100
# 23      CFM_095  DISENCHANT_GOLDEN   400
# 24      BRM_018    CRAFTING_NORMAL   100
# 25      BRM_018    CRAFTING_GOLDEN   800
# 26      BRM_018  DISENCHANT_NORMAL    20
# 27      BRM_018  DISENCHANT_GOLDEN   100
# 28       OG_027    CRAFTING_NORMAL   100
# 29       OG_027    CRAFTING_GOLDEN   800
# ...         ...                ...   ...
# 4010    tt_010a  DISENCHANT_NORMAL   100
# 4011    tt_010a  DISENCHANT_GOLDEN   400
# 4012    EX1_559    CRAFTING_NORMAL  1600
# 4013    EX1_559    CRAFTING_GOLDEN  3200
# 4014    EX1_559  DISENCHANT_NORMAL   400
# 4015    EX1_559  DISENCHANT_GOLDEN  1600
# 4016    EX1_624    CRAFTING_NORMAL   100
# 4017    EX1_624    CRAFTING_GOLDEN   800
# 4018    EX1_624  DISENCHANT_NORMAL    20
# 4019    EX1_624  DISENCHANT_GOLDEN   100
# 4020    OG_044a    CRAFTING_NORMAL    40
# 4021    OG_044a    CRAFTING_GOLDEN   400
# 4022    OG_044a  DISENCHANT_NORMAL     5
# 4023    OG_044a  DISENCHANT_GOLDEN    50
# 4024     AT_044    CRAFTING_NORMAL   400
# 4025     AT_044    CRAFTING_GOLDEN  1600
# 4026     AT_044  DISENCHANT_NORMAL   100
# 4027     AT_044  DISENCHANT_GOLDEN   400
# 4028   EX1_345t    CRAFTING_NORMAL   400
# 4029   EX1_345t    CRAFTING_GOLDEN  1600
# 4030   EX1_345t  DISENCHANT_NORMAL   100
# 4031   EX1_345t  DISENCHANT_GOLDEN   400
# 4032    EX1_009    CRAFTING_NORMAL   100
# 4033    EX1_009    CRAFTING_GOLDEN   800
# 4034    EX1_009  DISENCHANT_NORMAL    20
# 4035    EX1_009  DISENCHANT_GOLDEN   100
# 4036    CS2_031    CRAFTING_NORMAL    40
# 4037    CS2_031    CRAFTING_GOLDEN   400
# 4038    CS2_031  DISENCHANT_NORMAL     5
# 4039    CS2_031  DISENCHANT_GOLDEN    50
#
# [4040 rows x 3 columns]

# %% [markdown]
# ## Executing Joins
#
# Now that you have the tables loaded correctly, we're going to execute some joins. There are 4 different kinds of joins, which can best be visualized with venn diagrams:
#
# <img src='images/Image_198_joins.png'>
#
# In these diagrams, each circle represents a DataFrame or SQL Table.  The left table is the table you are working with, and the right table is the table you want to join to the table you are working with.  You'll start by executing the most common type of join, an **_Inner Join_**.
#
# In the cell below, join `cards_df` with `mechanics_df` using the built-in `.join()` method on the `cards_df` object.
#
# Pass in the following parameters:
# * the table you want to join with, `mechanics_df`
# * The `how` parameter set to the type of join you want, `'inner'`

# %%
cards_with_mechanics_df = cards_df.join(mechanics_df, how='inner', rsuffix = 'R')
cards_with_mechanics_df
# Out:
#                          card_id player_class         type  \
# 0                     KARA_00_07         MAGE        SPELL
# 1                      NEW1_008a        DRUID        SPELL
# 2                      BRM_010t2        DRUID       MINION
# 3                         AT_132      NEUTRAL       MINION
# 4                         OG_141      NEUTRAL       MINION
# 5                        CRED_17      NEUTRAL       MINION
# 6                        OG_337e      NEUTRAL  ENCHANTMENT
# 7                      BRMA08_1H      NEUTRAL         HERO
# 8                       GVG_011a      NEUTRAL  ENCHANTMENT
# 9                    NAX8_02H_TB      NEUTRAL   HERO_POWER
# 10                        AT_131      NEUTRAL       MINION
# 11                      CS2_122e      NEUTRAL  ENCHANTMENT
# 12                   LOEA05_02ha      NEUTRAL   HERO_POWER
# 13             CS2_102_H1_AT_132      WARRIOR   HERO_POWER
# 14                      CFM_334e      NEUTRAL  ENCHANTMENT
# 15                       EX1_583      NEUTRAL       MINION
# 16        TB_PickYourFate_11rand      NEUTRAL        SPELL
# 17                      LOE_007t      WARLOCK        SPELL
# 18                       CFM_095      NEUTRAL       MINION
# 19                       BRM_018      PALADIN       MINION
# 20                      PRO_001a      NEUTRAL        SPELL
# 21                     BRMA10_5H      NEUTRAL       MINION
# 22                      BRMA11_1      NEUTRAL         HERO
# 23                        OG_027       SHAMAN        SPELL
# 24                       NAX1_01      NEUTRAL         HERO
# 25                       GVG_030        DRUID       MINION
# 26                       CFM_094      WARLOCK        SPELL
# 27                   DS1h_292_H1       HUNTER   HERO_POWER
# 28                       CS2_227      NEUTRAL       MINION
# 29                       KAR_062      NEUTRAL       MINION
# ...                          ...          ...          ...
# 1049                      AT_017      NEUTRAL       MINION
# 1050                    LOEA12_1      NEUTRAL         HERO
# 1051                     GVG_035        DRUID       MINION
# 1052                     OG_104e      NEUTRAL  ENCHANTMENT
# 1053                     CS2_119      NEUTRAL       MINION
# 1054                     LOE_003         MAGE       MINION
# 1055                    LOE_113e      NEUTRAL  ENCHANTMENT
# 1056                      OG_284      NEUTRAL       MINION
# 1057                     EX1_611       HUNTER        SPELL
# 1058                      OG_340      NEUTRAL       MINION
# 1059                      OG_323      NEUTRAL       MINION
# 1060                     NAX8_03      NEUTRAL       MINION
# 1061                   LOE_089t3      NEUTRAL       MINION
# 1062                    TU4e_001       HUNTER         HERO
# 1063                     GVG_031        DRUID        SPELL
# 1064                     EX1_558      NEUTRAL       MINION
# 1065                     EX1_116      NEUTRAL       MINION
# 1066  TB_MechWar_Boss1_HeroPower      NEUTRAL   HERO_POWER
# 1067                   LOEA07_09      NEUTRAL       MINION
# 1068                      AT_114      NEUTRAL       MINION
# 1069           TB_PickYourFate_6      NEUTRAL        SPELL
# 1070                    AT_074e2      PALADIN  ENCHANTMENT
# 1071            KARA_09_07heroic      NEUTRAL        SPELL
# 1072                      AT_021      WARLOCK       MINION
# 1073                    GAME_004      NEUTRAL  ENCHANTMENT
# 1074              AT_132_SHAMANb       SHAMAN       MINION
# 1075                     BRM_014       HUNTER       MINION
# 1076                    CFM_617e      NEUTRAL  ENCHANTMENT
# 1077                   LOEA16_3e      NEUTRAL  ENCHANTMENT
# 1078                     CS2_121      NEUTRAL       MINION
#
#                          name         set  \
# 0               Astral Portal        KARA
# 1           Ancient Teachings     EXPERT1
# 2          Druid of the Flame         BRM
# 3          Justicar Trueheart         TGT
# 4           Faceless Behemoth          OG
# 5                   Rob Pardo     CREDITS
# 6          Eve of Destruction          OG
# 7          General Drakkisath         BRM
# 8                  Shrink Ray         GVG
# 9                     Harvest          TB
# 10             Eydis Darkbane         TGT
# 11                   Enhanced        CORE
# 12        Trogg Hate Minions!         LOE
# 13                   Tank Up!  HERO_SKINS
# 14                  Smuggling       GANGS
# 15         Priestess of Elune     EXPERT1
# 16         Dire Fate: Murlocs          TB
# 17                    Cursed!         LOE
# 18            Weasel Tunneler       GANGS
# 19             Dragon Consort         BRM
# 20                I Am Murloc       PROMO
# 21            Chromatic Drake         BRM
# 22    Vaelastrasz the Corrupt         BRM
# 23                     Evolve          OG
# 24                Anub'Rekhan        NAXX
# 25          Anodized Robo Cub         GVG
# 26             Felfire Potion       GANGS
# 27                Steady Shot  HERO_SKINS
# 28      Venture Co. Mercenary     EXPERT1
# 29      Netherspite Historian        KARA
# ...                       ...         ...
# 1049        Twilight Guardian         TGT
# 1050             Lady Naz'jar         LOE
# 1051                  Malorne         GVG
# 1052     Embracing the Shadow          OG
# 1053            Oasis Snapjaw        CORE
# 1054        Ethereal Conjurer         LOE
# 1055      Mrglllraawrrrglrur!         LOE
# 1056       Twilight Geomancer          OG
# 1057            Freezing Trap     EXPERT1
# 1058    Soggoth the Slitherer          OG
# 1059         Polluted Hoarder          OG
# 1060      Unrelenting Trainee        NAXX
# 1061             Grumbly Runt         LOE
# 1062        Illidan Stormrage    MISSIONS
# 1063                  Recycle         GVG
# 1064           Harrison Jones     EXPERT1
# 1065           Leeroy Jenkins     EXPERT1
# 1066     Hello! Hello! Hello!          TB
# 1067            Chasing Trogg         LOE
# 1068             Evil Heckler         TGT
# 1069            Fate: Portals          TB
# 1070        Seal of Champions         TGT
# 1071               Steal Life        KARA
# 1072      Tiny Knight of Evil         TGT
# 1073                      AFK        CORE
# 1074            Searing Totem         TGT
# 1075               Core Rager         BRM
# 1076        Visions of Hypnos       GANGS
# 1077         Lantern of Power         LOE
# 1078          Frostwolf Grunt        CORE
#
#                                                    text  cost  attack  health  \
# 0              Summon a random <b>Legendary</b> minion.   1.0     NaN     NaN
# 1                                          Draw a card.   0.0     NaN     NaN
# 2                                                   NaN   3.0     2.0     5.0
# 3     <b>Battlecry:</b> Replace your starting Hero P...   6.0     6.0     3.0
# 4                                                   NaN  10.0    10.0    10.0
# 5     You can't start a game without this minion in ...   9.0     9.0     9.0
# 6                                      Stats increased.   NaN     NaN     NaN
# 7                                                   NaN   NaN     NaN    50.0
# 8                                  -2 Attack this turn.   NaN     NaN     NaN
# 9     <b>Hero Power</b>\nDraw a card. Gain a Mana Cr...   2.0     NaN     NaN
# 10    Whenever <b>you</b> target this minion with a ...   3.0     3.0     4.0
# 11       Raid Leader is granting this minion +1 Attack.   NaN     NaN     NaN
# 12    <b>Passive Hero Power</b>\n Enemy minions cost...   0.0     NaN     NaN
# 13                     <b>Hero Power</b>\nGain 4 Armor.   2.0     NaN     NaN
# 14                         +2/+2 from Smuggler's Crate.   NaN     NaN     NaN
# 15     <b>Battlecry:</b> Restore 4 Health to your hero.   6.0     5.0     4.0
# 16          Turn each minion in play into a 1/1 Murloc.   0.0     NaN     NaN
# 17    While this is in your hand, take 2 damage at t...   2.0     NaN     NaN
# 18    <b>Deathrattle:</b> Shuffle this minion into y...   1.0     1.0     1.0
# 19    <b>Battlecry:</b> The next Dragon you play cos...   5.0     5.0     5.0
# 20             Summon three, four, or five 1/1 Murlocs.   4.0     NaN     NaN
# 21                                                  NaN   4.0     7.0     7.0
# 22                                                  NaN   NaN     NaN    30.0
# 23    Transform your minions into random minions tha...   1.0     NaN     NaN
# 24                                                  NaN   NaN     NaN    30.0
# 25    <b>Taunt</b>. <b>Choose One -</b>\n+1 Attack; ...   2.0     2.0     2.0
# 26                    Deal $5 damage to all characters.   6.0     NaN     NaN
# 27    <b>Hero Power</b>\nDeal $2 damage to the enemy...   2.0     NaN     NaN
# 28                          Your minions cost (3) more.   5.0     7.0     6.0
# 29    <b>Battlecry:</b> If you're holding a Dragon, ...   2.0     1.0     3.0
# ...                                                 ...   ...     ...     ...
# 1049  <b>Battlecry:</b> If you're holding a Dragon, ...   4.0     2.0     6.0
# 1050                                                NaN   NaN     NaN    30.0
# 1051  <b>Deathrattle:</b> Shuffle this minion into y...   7.0     9.0     7.0
# 1052           Your healing effects are dealing damage.   NaN     NaN     NaN
# 1053                                                NaN   4.0     2.0     7.0
# 1054                <b>Battlecry: Discover</b> a spell.   5.0     6.0     3.0
# 1055                                             +2/+2.   NaN     NaN     NaN
# 1056  [x]<b>Taunt</b>\n<b>Battlecry:</b> Give your C...   2.0     1.0     4.0
# 1057  <b>Secret:</b> When an enemy minion attacks, r...   2.0     NaN     NaN
# 1058  <b>Taunt</b>\nCan't be targeted by spells or H...   9.0     5.0     9.0
# 1059                   <b>Deathrattle:</b> Draw a card.   4.0     4.0     2.0
# 1060  <b>Deathrattle:</b> Summon a Spectral Trainee ...   1.0     2.0     2.0
# 1061                                                NaN   2.0     2.0     2.0
# 1062                                                NaN   NaN     NaN    30.0
# 1063  Shuffle an enemy minion into your opponent's d...   6.0     NaN     NaN
# 1064  <b>Battlecry:</b> Destroy your opponent's weap...   5.0     5.0     4.0
# 1065  <b>Charge</b>. <b>Battlecry:</b> Summon two 1/...   5.0     6.0     2.0
# 1066  <b>Hero Power</b>\nGive your lowest attack min...   2.0     NaN     NaN
# 1067                                                NaN   4.0     2.0     6.0
# 1068                                       <b>Taunt</b>   4.0     5.0     4.0
# 1069  Shuffle 10 Unstable Portals into each player's...   0.0     NaN     NaN
# 1070                +3 Attack and <b>Divine Shield</b>.   NaN     NaN     NaN
# 1071    Deal $5 damage. Restore #5 Health to your hero.   4.0     NaN     NaN
# 1072           Whenever you discard a card, gain +1/+1.   2.0     3.0     2.0
# 1073                            Your turns are shorter.   NaN     NaN     NaN
# 1074                                                NaN   0.0     1.0     1.0
# 1075  <b>Battlecry:</b> If your hand is empty, gain ...   4.0     4.0     4.0
# 1076                                             +2/+2.   NaN     NaN     NaN
# 1077                                           +10/+10.   NaN     NaN     NaN
# 1078                                       <b>Taunt</b>   2.0     2.0     2.0
#
#          rarity  collectible  \
# 0           NaN          NaN
# 1           NaN          NaN
# 2        COMMON          NaN
# 3     LEGENDARY          1.0
# 4        COMMON          1.0
# 5     LEGENDARY          NaN
# 6           NaN          NaN
# 7           NaN          NaN
# 8           NaN          NaN
# 9           NaN          NaN
# 10    LEGENDARY          1.0
# 11          NaN          NaN
# 12          NaN          NaN
# 13          NaN          NaN
# 14          NaN          NaN
# 15       COMMON          1.0
# 16          NaN          NaN
# 17          NaN          NaN
# 18         EPIC          1.0
# 19         RARE          1.0
# 20          NaN          NaN
# 21          NaN          NaN
# 22          NaN          NaN
# 23         RARE          1.0
# 24          NaN          NaN
# 25       COMMON          1.0
# 26         RARE          1.0
# 27         FREE          NaN
# 28       COMMON          1.0
# 29       COMMON          1.0
# ...         ...          ...
# 1049       EPIC          1.0
# 1050        NaN          NaN
# 1051  LEGENDARY          1.0
# 1052        NaN          NaN
# 1053       FREE          1.0
# 1054     COMMON          1.0
# 1055        NaN          NaN
# 1056     COMMON          1.0
# 1057     COMMON          1.0
# 1058  LEGENDARY          1.0
# 1059     COMMON          1.0
# 1060        NaN          NaN
# 1061        NaN          NaN
# 1062        NaN          NaN
# 1063       RARE          1.0
# 1064  LEGENDARY          1.0
# 1065  LEGENDARY          1.0
# 1066        NaN          NaN
# 1067        NaN          NaN
# 1068     COMMON          1.0
# 1069        NaN          NaN
# 1070        NaN          NaN
# 1071        NaN          NaN
# 1072       RARE          1.0
# 1073        NaN          NaN
# 1074        NaN          NaN
# 1075       RARE          1.0
# 1076        NaN          NaN
# 1077        NaN          NaN
# 1078     COMMON          1.0
#
#                                                  flavor        race  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN       BEAST
# 3     It's like putting racing stripes and a giant s...         NaN
# 4     Rejected names: Forty-Foot Faceless, Big ol' N...         NaN
# 5                                                   NaN         NaN
# 6                                                   NaN         NaN
# 7                                                   NaN         NaN
# 8                                                   NaN         NaN
# 9                                                   NaN         NaN
# 10               HATES being called "the wonder twins".         NaN
# 11                                                  NaN         NaN
# 12                                                  NaN         NaN
# 13                                                  NaN         NaN
# 14                                                  NaN         NaN
# 15    If she threatens to "moon" you, it's not what ...         NaN
# 16                                                  NaN         NaN
# 17                                                  NaN         NaN
# 18    He's the reason the First Bank of Gadgetzan ha...       BEAST
# 19    Everybody wants someone to snuggle with. Even ...      DRAGON
# 20                                                  NaN         NaN
# 21                                                  NaN      DRAGON
# 22                                                  NaN         NaN
# 23    So you say you want an evolution. Well, you kn...         NaN
# 24                                                  NaN         NaN
# 25    It's adorable! AND OH MY GOODNESS WHY IS IT EA...  MECHANICAL
# 26    Kazakus has a squad of imps bottling Felfire r...         NaN
# 27                                                  NaN         NaN
# 28               No Job is too big.  No fee is too big.         NaN
# 29    She can tell you all about the history of peop...         NaN
# ...                                                 ...         ...
# 1049  A result of magical experiments carried out by...      DRAGON
# 1050                                                NaN         NaN
# 1051  When Malorne isn't mauling hordes of demons, h...       BEAST
# 1052                                                NaN         NaN
# 1053  His dreams of flying and breathing fire like h...       BEAST
# 1054           Despite the name, he's a solid conjurer.         NaN
# 1055                                                NaN         NaN
# 1056  "Ok C'Thun, repeat after me: 'Your mother was ...         NaN
# 1057  "Dang, that's cold." - appropriate response to...         NaN
# 1058  Don't tell Soggoth, but in the future he gets ...         NaN
# 1059          Roll ‘greed’ OR THIS COULD HAPPEN TO YOU.         NaN
# 1060                                                NaN         NaN
# 1061                                                NaN         NaN
# 1062                                                NaN         NaN
# 1063  Druidic recycling involves putting plastics in...         NaN
# 1064           “That belongs in the Hall of Explorers!”         NaN
# 1065                     At least he has Angry Chicken.         NaN
# 1066                                                NaN         NaN
# 1067                                                NaN         NaN
# 1068  To be honest, heckling is not the most effecti...         NaN
# 1069                                                NaN         NaN
# 1070                                                NaN         NaN
# 1071                                                NaN         NaN
# 1072   "No, no, no. I asked for a tiny JESTER of evil."       DEMON
# 1073                                                NaN         NaN
# 1074                                                NaN         NaN
# 1075  It takes a special kind of hunter to venture d...       BEAST
# 1076                                                NaN         NaN
# 1077                                                NaN         NaN
# 1078  Grunting is what his father did and his father...         NaN
#
#                                             how_to_earn  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19    Unlocked in Blackrock Spire, in the Blackrock ...
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29     Unlocked in the Spire, in One Night in Karazhan.
# ...                                                 ...
# 1049                                                NaN
# 1050                                                NaN
# 1051                                                NaN
# 1052                                                NaN
# 1053                                                NaN
# 1054  Unlocked in Uldaman, in the League of Explorer...
# 1055                                                NaN
# 1056                                                NaN
# 1057                                                NaN
# 1058                                                NaN
# 1059                                                NaN
# 1060                                                NaN
# 1061                                                NaN
# 1062                                                NaN
# 1063                                                NaN
# 1064                                                NaN
# 1065                                                NaN
# 1066                                                NaN
# 1067                                                NaN
# 1068                                                NaN
# 1069                                                NaN
# 1070                                                NaN
# 1071                                                NaN
# 1072                                                NaN
# 1073                                                NaN
# 1074                                                NaN
# 1075  Unlocked in Blackrock Spire, in the Blackrock ...
# 1076                                                NaN
# 1077                                                NaN
# 1078                                                NaN
#
#                                      how_to_earn_golden targeting_arrow_text  \
# 0                                                   NaN                  NaN
# 1                                                   NaN                  NaN
# 2                                                   NaN                  NaN
# 3                                                   NaN                  NaN
# 4                                                   NaN                  NaN
# 5                                                   NaN                  NaN
# 6                                                   NaN                  NaN
# 7                                                   NaN                  NaN
# 8                                                   NaN                  NaN
# 9                                                   NaN                  NaN
# 10                                                  NaN                  NaN
# 11                                                  NaN                  NaN
# 12                                                  NaN                  NaN
# 13                                                  NaN                  NaN
# 14                                                  NaN                  NaN
# 15                                                  NaN                  NaN
# 16                                                  NaN                  NaN
# 17                                                  NaN                  NaN
# 18                                                  NaN                  NaN
# 19    Crafting unlocked in Blackrock Spire, in the B...                  NaN
# 20                                                  NaN                  NaN
# 21                                                  NaN                  NaN
# 22                                                  NaN                  NaN
# 23                                                  NaN                  NaN
# 24                                                  NaN                  NaN
# 25                                                  NaN                  NaN
# 26                                                  NaN                  NaN
# 27                                                  NaN                  NaN
# 28                                                  NaN                  NaN
# 29    Crafting unlocked in the Spire, in One Night i...                  NaN
# ...                                                 ...                  ...
# 1049                                                NaN                  NaN
# 1050                                                NaN                  NaN
# 1051                                                NaN                  NaN
# 1052                                                NaN                  NaN
# 1053                        Unlocked at Druid Level 51.                  NaN
# 1054  Crafting unlocked in Uldaman, in the League of...                  NaN
# 1055                                                NaN                  NaN
# 1056                                                NaN                  NaN
# 1057                                                NaN                  NaN
# 1058                                                NaN                  NaN
# 1059                                                NaN                  NaN
# 1060                                                NaN                  NaN
# 1061                                                NaN                  NaN
# 1062                                                NaN                  NaN
# 1063                                                NaN                  NaN
# 1064                                                NaN                  NaN
# 1065                                                NaN                  NaN
# 1066                                                NaN                  NaN
# 1067                                                NaN                  NaN
# 1068                                                NaN                  NaN
# 1069                                                NaN                  NaN
# 1070                                                NaN                  NaN
# 1071                                                NaN                  NaN
# 1072                                                NaN                  NaN
# 1073                                                NaN                  NaN
# 1074                                                NaN                  NaN
# 1075  Crafting unlocked in Blackrock Spire, in the B...                  NaN
# 1076                                                NaN                  NaN
# 1077                                                NaN                  NaN
# 1078                       Unlocked at Shaman Level 57.                  NaN
#
#        faction  durability            card_idR             mechanic
# 0          NaN         NaN              AT_132            BATTLECRY
# 1          NaN         NaN            GVG_011a  TAG_ONE_TURN_EFFECT
# 2          NaN         NaN             EX1_583            BATTLECRY
# 3          NaN         NaN            LOE_007t            EVIL_GLOW
# 4          NaN         NaN            LOE_007t   ImmuneToSpellpower
# 5          NaN         NaN             CFM_095          DEATHRATTLE
# 6          NaN         NaN             BRM_018            BATTLECRY
# 7          NaN         NaN             GVG_030           CHOOSE_ONE
# 8          NaN         NaN             GVG_030                TAUNT
# 9          NaN         NaN             CS2_227                 AURA
# 10         NaN         NaN             KAR_062            BATTLECRY
# 11         NaN         NaN         CFM_712_t17           JADE_GOLEM
# 12         NaN         NaN            BRM_011t  TAG_ONE_TURN_EFFECT
# 13         NaN         NaN           BRMA10_3H         AI_MUST_PLAY
# 14         NaN         NaN            KAR_710m                TAUNT
# 15         NaN         NaN            EX1_295o  TAG_ONE_TURN_EFFECT
# 16         NaN         NaN              OG_158          DEATHRATTLE
# 17         NaN         NaN            LOE_110t              TOPDECK
# 18         NaN         NaN            LOE_110t   ImmuneToSpellpower
# 19         NaN         NaN           BRMA13_4H         AI_MUST_PLAY
# 20         NaN         NaN            EX1_145o  TAG_ONE_TURN_EFFECT
# 21         NaN         NaN           LOEA09_2e  TAG_ONE_TURN_EFFECT
# 22         NaN         NaN            EX1_570e  TAG_ONE_TURN_EFFECT
# 23         NaN         NaN             GVG_069            BATTLECRY
# 24         NaN         NaN             hexfrog                TAUNT
# 25         NaN         NaN              OG_145        DIVINE_SHIELD
# 26         NaN         NaN              OG_145                TAUNT
# 27         NaN         NaN              AT_090              INSPIRE
# 28       HORDE         NaN              AT_060               SECRET
# 29         NaN         NaN  TB_MechWar_Minion1                TAUNT
# ...        ...         ...                 ...                  ...
# 1049       NaN         NaN             EX1_284            BATTLECRY
# 1050       NaN         NaN             LOE_038                 AURA
# 1051       NaN         NaN              AT_083              INSPIRE
# 1052       NaN         NaN    TB_CoOpv3_BOSS2e              ENRAGED
# 1053       NaN         NaN             GVG_009            BATTLECRY
# 1054       NaN         NaN             CFM_338            BATTLECRY
# 1055       NaN         NaN             GVG_097            BATTLECRY
# 1056       NaN         NaN             GVG_097                TAUNT
# 1057       NaN         NaN             CFM_852            BATTLECRY
# 1058       NaN         NaN             LOE_020            BATTLECRY
# 1059       NaN         NaN             CFM_781              STEALTH
# 1060       NaN         NaN             GVG_090            BATTLECRY
# 1061       NaN         NaN             GVG_120            BATTLECRY
# 1062       NaN         NaN            EX1_055o  TAG_ONE_TURN_EFFECT
# 1063       NaN         NaN             CFM_321            BATTLECRY
# 1064       NaN         NaN             EX1_082            BATTLECRY
# 1065  ALLIANCE         NaN             FP1_017                 AURA
# 1066       NaN         NaN             FP1_001          DEATHRATTLE
# 1067       NaN         NaN              AT_089              INSPIRE
# 1068       NaN         NaN             CFM_646          DEATHRATTLE
# 1069       NaN         NaN              AT_084            BATTLECRY
# 1070       NaN         NaN             OG_044a               CHARGE
# 1071       NaN         NaN             OG_044a                TAUNT
# 1072       NaN         NaN           LOEA09_3d         AI_MUST_PLAY
# 1073       NaN         NaN            BRMA13_4         AI_MUST_PLAY
# 1074       NaN         NaN             EX1_009              ENRAGED
# 1075       NaN         NaN            BRMA10_3         AI_MUST_PLAY
# 1076       NaN         NaN            NAX3_02H         AI_MUST_PLAY
# 1077       NaN         NaN             AT_083e  TAG_ONE_TURN_EFFECT
# 1078       NaN         NaN             CS2_031               FREEZE
#
# [1079 rows x 20 columns]

# %% [markdown]
# Examine the output from the cell above and compare it to the original output of both the `cards_df` and `mechanics_df` DataFrame heads you displayed earlier.  Notice how it this now combines the columns from both?
#
# **_Question_**
#
# If you inspect the original `cards_df` DataFrame, you'll notice that it contains  2,819 records.  The result of our inner join, `cards_with_mechanics_df`, conntains only 1079 rows.  Why?
#
# Write your answer below this line:
# ________________________________________________________________________________
#
# First performed an inner join, which only includes records that are present in both tables.  Although there were 2819 records in the left table, there were only 1079 records that existed in both tables, which are what you see in the resulting dataframe.
#
# ## Other Types of Joins
#
# By default, the `.join()` method performs a left join if no parameter is passed in for `how=`.  In the cell below, perform a **_Left Join_** of `cards_with_mechanics_df` and `play_requirements_df`, with `cards_with_mechanics_df` as the left table.
#
# Then, display `left_join_df` to inspect our results.

# %%
left_join_df = cards_with_mechanics_df.join(play_requirements.csv)
left_join_df
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-9-4fb199cbea35> in <module>()
# ----> 1 left_join_df = cards_with_mechanics_df.join(play_requirements.csv)
#       2 left_join_df
#
# NameError: name 'cards_with_mechanics_df' is not defined

# %% [markdown]
# Note that the results of this sort of join are dependent upon the position of each table--if you were to make `cards_with_mechanics_df` the right table and `play_requirements_df` the left table and then perform a **_Right Join_**, our results would be the same.
#
# **_Question:_**
#
# Describe what was included from each table in this join.
#
# Write your answer below this line:
# ________________________________________________________________________________
#
# Every record from `cards_with_mechanics_df`, as well as any records from `play_requirements_df` that have matching index values with a record from the left table.
#
# #### Outer Joins
#
# In the cell below, perform an outer join between `cards_df` and `dust_df`. Since these tables contain columns with the same name, we'll need to specify a suffix for at least one of them, so that the column can be renamed to avoid a naming collision.
#
# During this join, set the `rsuffix` parameter to `_dust`

# %%
outer_join_df = cards_df.join(dust_df, how='outer', rsuffix='_dust')
outer_join_df
# Out:
#                      card_id player_class         type  \
# 0                 KARA_00_07         MAGE        SPELL
# 1                  NEW1_008a        DRUID        SPELL
# 2                  BRM_010t2        DRUID       MINION
# 3                     AT_132      NEUTRAL       MINION
# 4                     OG_141      NEUTRAL       MINION
# 5                    CRED_17      NEUTRAL       MINION
# 6                    OG_337e      NEUTRAL  ENCHANTMENT
# 7                  BRMA08_1H      NEUTRAL         HERO
# 8                   GVG_011a      NEUTRAL  ENCHANTMENT
# 9                NAX8_02H_TB      NEUTRAL   HERO_POWER
# 10                    AT_131      NEUTRAL       MINION
# 11                  CS2_122e      NEUTRAL  ENCHANTMENT
# 12               LOEA05_02ha      NEUTRAL   HERO_POWER
# 13         CS2_102_H1_AT_132      WARRIOR   HERO_POWER
# 14                  CFM_334e      NEUTRAL  ENCHANTMENT
# 15                   EX1_583      NEUTRAL       MINION
# 16    TB_PickYourFate_11rand      NEUTRAL        SPELL
# 17                  LOE_007t      WARLOCK        SPELL
# 18                   CFM_095      NEUTRAL       MINION
# 19                   BRM_018      PALADIN       MINION
# 20                  PRO_001a      NEUTRAL        SPELL
# 21                 BRMA10_5H      NEUTRAL       MINION
# 22                  BRMA11_1      NEUTRAL         HERO
# 23                    OG_027       SHAMAN        SPELL
# 24                   NAX1_01      NEUTRAL         HERO
# 25                   GVG_030        DRUID       MINION
# 26                   CFM_094      WARLOCK        SPELL
# 27               DS1h_292_H1       HUNTER   HERO_POWER
# 28                   CS2_227      NEUTRAL       MINION
# 29                   KAR_062      NEUTRAL       MINION
# ...                      ...          ...          ...
# 4010                     NaN          NaN          NaN
# 4011                     NaN          NaN          NaN
# 4012                     NaN          NaN          NaN
# 4013                     NaN          NaN          NaN
# 4014                     NaN          NaN          NaN
# 4015                     NaN          NaN          NaN
# 4016                     NaN          NaN          NaN
# 4017                     NaN          NaN          NaN
# 4018                     NaN          NaN          NaN
# 4019                     NaN          NaN          NaN
# 4020                     NaN          NaN          NaN
# 4021                     NaN          NaN          NaN
# 4022                     NaN          NaN          NaN
# 4023                     NaN          NaN          NaN
# 4024                     NaN          NaN          NaN
# 4025                     NaN          NaN          NaN
# 4026                     NaN          NaN          NaN
# 4027                     NaN          NaN          NaN
# 4028                     NaN          NaN          NaN
# 4029                     NaN          NaN          NaN
# 4030                     NaN          NaN          NaN
# 4031                     NaN          NaN          NaN
# 4032                     NaN          NaN          NaN
# 4033                     NaN          NaN          NaN
# 4034                     NaN          NaN          NaN
# 4035                     NaN          NaN          NaN
# 4036                     NaN          NaN          NaN
# 4037                     NaN          NaN          NaN
# 4038                     NaN          NaN          NaN
# 4039                     NaN          NaN          NaN
#
#                          name         set  \
# 0               Astral Portal        KARA
# 1           Ancient Teachings     EXPERT1
# 2          Druid of the Flame         BRM
# 3          Justicar Trueheart         TGT
# 4           Faceless Behemoth          OG
# 5                   Rob Pardo     CREDITS
# 6          Eve of Destruction          OG
# 7          General Drakkisath         BRM
# 8                  Shrink Ray         GVG
# 9                     Harvest          TB
# 10             Eydis Darkbane         TGT
# 11                   Enhanced        CORE
# 12        Trogg Hate Minions!         LOE
# 13                   Tank Up!  HERO_SKINS
# 14                  Smuggling       GANGS
# 15         Priestess of Elune     EXPERT1
# 16         Dire Fate: Murlocs          TB
# 17                    Cursed!         LOE
# 18            Weasel Tunneler       GANGS
# 19             Dragon Consort         BRM
# 20                I Am Murloc       PROMO
# 21            Chromatic Drake         BRM
# 22    Vaelastrasz the Corrupt         BRM
# 23                     Evolve          OG
# 24                Anub'Rekhan        NAXX
# 25          Anodized Robo Cub         GVG
# 26             Felfire Potion       GANGS
# 27                Steady Shot  HERO_SKINS
# 28      Venture Co. Mercenary     EXPERT1
# 29      Netherspite Historian        KARA
# ...                       ...         ...
# 4010                      NaN         NaN
# 4011                      NaN         NaN
# 4012                      NaN         NaN
# 4013                      NaN         NaN
# 4014                      NaN         NaN
# 4015                      NaN         NaN
# 4016                      NaN         NaN
# 4017                      NaN         NaN
# 4018                      NaN         NaN
# 4019                      NaN         NaN
# 4020                      NaN         NaN
# 4021                      NaN         NaN
# 4022                      NaN         NaN
# 4023                      NaN         NaN
# 4024                      NaN         NaN
# 4025                      NaN         NaN
# 4026                      NaN         NaN
# 4027                      NaN         NaN
# 4028                      NaN         NaN
# 4029                      NaN         NaN
# 4030                      NaN         NaN
# 4031                      NaN         NaN
# 4032                      NaN         NaN
# 4033                      NaN         NaN
# 4034                      NaN         NaN
# 4035                      NaN         NaN
# 4036                      NaN         NaN
# 4037                      NaN         NaN
# 4038                      NaN         NaN
# 4039                      NaN         NaN
#
#                                                    text  cost  attack  health  \
# 0              Summon a random <b>Legendary</b> minion.   1.0     NaN     NaN
# 1                                          Draw a card.   0.0     NaN     NaN
# 2                                                   NaN   3.0     2.0     5.0
# 3     <b>Battlecry:</b> Replace your starting Hero P...   6.0     6.0     3.0
# 4                                                   NaN  10.0    10.0    10.0
# 5     You can't start a game without this minion in ...   9.0     9.0     9.0
# 6                                      Stats increased.   NaN     NaN     NaN
# 7                                                   NaN   NaN     NaN    50.0
# 8                                  -2 Attack this turn.   NaN     NaN     NaN
# 9     <b>Hero Power</b>\nDraw a card. Gain a Mana Cr...   2.0     NaN     NaN
# 10    Whenever <b>you</b> target this minion with a ...   3.0     3.0     4.0
# 11       Raid Leader is granting this minion +1 Attack.   NaN     NaN     NaN
# 12    <b>Passive Hero Power</b>\n Enemy minions cost...   0.0     NaN     NaN
# 13                     <b>Hero Power</b>\nGain 4 Armor.   2.0     NaN     NaN
# 14                         +2/+2 from Smuggler's Crate.   NaN     NaN     NaN
# 15     <b>Battlecry:</b> Restore 4 Health to your hero.   6.0     5.0     4.0
# 16          Turn each minion in play into a 1/1 Murloc.   0.0     NaN     NaN
# 17    While this is in your hand, take 2 damage at t...   2.0     NaN     NaN
# 18    <b>Deathrattle:</b> Shuffle this minion into y...   1.0     1.0     1.0
# 19    <b>Battlecry:</b> The next Dragon you play cos...   5.0     5.0     5.0
# 20             Summon three, four, or five 1/1 Murlocs.   4.0     NaN     NaN
# 21                                                  NaN   4.0     7.0     7.0
# 22                                                  NaN   NaN     NaN    30.0
# 23    Transform your minions into random minions tha...   1.0     NaN     NaN
# 24                                                  NaN   NaN     NaN    30.0
# 25    <b>Taunt</b>. <b>Choose One -</b>\n+1 Attack; ...   2.0     2.0     2.0
# 26                    Deal $5 damage to all characters.   6.0     NaN     NaN
# 27    <b>Hero Power</b>\nDeal $2 damage to the enemy...   2.0     NaN     NaN
# 28                          Your minions cost (3) more.   5.0     7.0     6.0
# 29    <b>Battlecry:</b> If you're holding a Dragon, ...   2.0     1.0     3.0
# ...                                                 ...   ...     ...     ...
# 4010                                                NaN   NaN     NaN     NaN
# 4011                                                NaN   NaN     NaN     NaN
# 4012                                                NaN   NaN     NaN     NaN
# 4013                                                NaN   NaN     NaN     NaN
# 4014                                                NaN   NaN     NaN     NaN
# 4015                                                NaN   NaN     NaN     NaN
# 4016                                                NaN   NaN     NaN     NaN
# 4017                                                NaN   NaN     NaN     NaN
# 4018                                                NaN   NaN     NaN     NaN
# 4019                                                NaN   NaN     NaN     NaN
# 4020                                                NaN   NaN     NaN     NaN
# 4021                                                NaN   NaN     NaN     NaN
# 4022                                                NaN   NaN     NaN     NaN
# 4023                                                NaN   NaN     NaN     NaN
# 4024                                                NaN   NaN     NaN     NaN
# 4025                                                NaN   NaN     NaN     NaN
# 4026                                                NaN   NaN     NaN     NaN
# 4027                                                NaN   NaN     NaN     NaN
# 4028                                                NaN   NaN     NaN     NaN
# 4029                                                NaN   NaN     NaN     NaN
# 4030                                                NaN   NaN     NaN     NaN
# 4031                                                NaN   NaN     NaN     NaN
# 4032                                                NaN   NaN     NaN     NaN
# 4033                                                NaN   NaN     NaN     NaN
# 4034                                                NaN   NaN     NaN     NaN
# 4035                                                NaN   NaN     NaN     NaN
# 4036                                                NaN   NaN     NaN     NaN
# 4037                                                NaN   NaN     NaN     NaN
# 4038                                                NaN   NaN     NaN     NaN
# 4039                                                NaN   NaN     NaN     NaN
#
#          rarity    ...                                                flavor  \
# 0           NaN    ...                                                   NaN
# 1           NaN    ...                                                   NaN
# 2        COMMON    ...                                                   NaN
# 3     LEGENDARY    ...     It's like putting racing stripes and a giant s...
# 4        COMMON    ...     Rejected names: Forty-Foot Faceless, Big ol' N...
# 5     LEGENDARY    ...                                                   NaN
# 6           NaN    ...                                                   NaN
# 7           NaN    ...                                                   NaN
# 8           NaN    ...                                                   NaN
# 9           NaN    ...                                                   NaN
# 10    LEGENDARY    ...                HATES being called "the wonder twins".
# 11          NaN    ...                                                   NaN
# 12          NaN    ...                                                   NaN
# 13          NaN    ...                                                   NaN
# 14          NaN    ...                                                   NaN
# 15       COMMON    ...     If she threatens to "moon" you, it's not what ...
# 16          NaN    ...                                                   NaN
# 17          NaN    ...                                                   NaN
# 18         EPIC    ...     He's the reason the First Bank of Gadgetzan ha...
# 19         RARE    ...     Everybody wants someone to snuggle with. Even ...
# 20          NaN    ...                                                   NaN
# 21          NaN    ...                                                   NaN
# 22          NaN    ...                                                   NaN
# 23         RARE    ...     So you say you want an evolution. Well, you kn...
# 24          NaN    ...                                                   NaN
# 25       COMMON    ...     It's adorable! AND OH MY GOODNESS WHY IS IT EA...
# 26         RARE    ...     Kazakus has a squad of imps bottling Felfire r...
# 27         FREE    ...                                                   NaN
# 28       COMMON    ...                No Job is too big.  No fee is too big.
# 29       COMMON    ...     She can tell you all about the history of peop...
# ...         ...    ...                                                   ...
# 4010        NaN    ...                                                   NaN
# 4011        NaN    ...                                                   NaN
# 4012        NaN    ...                                                   NaN
# 4013        NaN    ...                                                   NaN
# 4014        NaN    ...                                                   NaN
# 4015        NaN    ...                                                   NaN
# 4016        NaN    ...                                                   NaN
# 4017        NaN    ...                                                   NaN
# 4018        NaN    ...                                                   NaN
# 4019        NaN    ...                                                   NaN
# 4020        NaN    ...                                                   NaN
# 4021        NaN    ...                                                   NaN
# 4022        NaN    ...                                                   NaN
# 4023        NaN    ...                                                   NaN
# 4024        NaN    ...                                                   NaN
# 4025        NaN    ...                                                   NaN
# 4026        NaN    ...                                                   NaN
# 4027        NaN    ...                                                   NaN
# 4028        NaN    ...                                                   NaN
# 4029        NaN    ...                                                   NaN
# 4030        NaN    ...                                                   NaN
# 4031        NaN    ...                                                   NaN
# 4032        NaN    ...                                                   NaN
# 4033        NaN    ...                                                   NaN
# 4034        NaN    ...                                                   NaN
# 4035        NaN    ...                                                   NaN
# 4036        NaN    ...                                                   NaN
# 4037        NaN    ...                                                   NaN
# 4038        NaN    ...                                                   NaN
# 4039        NaN    ...                                                   NaN
#
#             race                                        how_to_earn  \
# 0            NaN                                                NaN
# 1            NaN                                                NaN
# 2          BEAST                                                NaN
# 3            NaN                                                NaN
# 4            NaN                                                NaN
# 5            NaN                                                NaN
# 6            NaN                                                NaN
# 7            NaN                                                NaN
# 8            NaN                                                NaN
# 9            NaN                                                NaN
# 10           NaN                                                NaN
# 11           NaN                                                NaN
# 12           NaN                                                NaN
# 13           NaN                                                NaN
# 14           NaN                                                NaN
# 15           NaN                                                NaN
# 16           NaN                                                NaN
# 17           NaN                                                NaN
# 18         BEAST                                                NaN
# 19        DRAGON  Unlocked in Blackrock Spire, in the Blackrock ...
# 20           NaN                                                NaN
# 21        DRAGON                                                NaN
# 22           NaN                                                NaN
# 23           NaN                                                NaN
# 24           NaN                                                NaN
# 25    MECHANICAL                                                NaN
# 26           NaN                                                NaN
# 27           NaN                                                NaN
# 28           NaN                                                NaN
# 29           NaN   Unlocked in the Spire, in One Night in Karazhan.
# ...          ...                                                ...
# 4010         NaN                                                NaN
# 4011         NaN                                                NaN
# 4012         NaN                                                NaN
# 4013         NaN                                                NaN
# 4014         NaN                                                NaN
# 4015         NaN                                                NaN
# 4016         NaN                                                NaN
# 4017         NaN                                                NaN
# 4018         NaN                                                NaN
# 4019         NaN                                                NaN
# 4020         NaN                                                NaN
# 4021         NaN                                                NaN
# 4022         NaN                                                NaN
# 4023         NaN                                                NaN
# 4024         NaN                                                NaN
# 4025         NaN                                                NaN
# 4026         NaN                                                NaN
# 4027         NaN                                                NaN
# 4028         NaN                                                NaN
# 4029         NaN                                                NaN
# 4030         NaN                                                NaN
# 4031         NaN                                                NaN
# 4032         NaN                                                NaN
# 4033         NaN                                                NaN
# 4034         NaN                                                NaN
# 4035         NaN                                                NaN
# 4036         NaN                                                NaN
# 4037         NaN                                                NaN
# 4038         NaN                                                NaN
# 4039         NaN                                                NaN
#
#                                      how_to_earn_golden targeting_arrow_text  \
# 0                                                   NaN                  NaN
# 1                                                   NaN                  NaN
# 2                                                   NaN                  NaN
# 3                                                   NaN                  NaN
# 4                                                   NaN                  NaN
# 5                                                   NaN                  NaN
# 6                                                   NaN                  NaN
# 7                                                   NaN                  NaN
# 8                                                   NaN                  NaN
# 9                                                   NaN                  NaN
# 10                                                  NaN                  NaN
# 11                                                  NaN                  NaN
# 12                                                  NaN                  NaN
# 13                                                  NaN                  NaN
# 14                                                  NaN                  NaN
# 15                                                  NaN                  NaN
# 16                                                  NaN                  NaN
# 17                                                  NaN                  NaN
# 18                                                  NaN                  NaN
# 19    Crafting unlocked in Blackrock Spire, in the B...                  NaN
# 20                                                  NaN                  NaN
# 21                                                  NaN                  NaN
# 22                                                  NaN                  NaN
# 23                                                  NaN                  NaN
# 24                                                  NaN                  NaN
# 25                                                  NaN                  NaN
# 26                                                  NaN                  NaN
# 27                                                  NaN                  NaN
# 28                                                  NaN                  NaN
# 29    Crafting unlocked in the Spire, in One Night i...                  NaN
# ...                                                 ...                  ...
# 4010                                                NaN                  NaN
# 4011                                                NaN                  NaN
# 4012                                                NaN                  NaN
# 4013                                                NaN                  NaN
# 4014                                                NaN                  NaN
# 4015                                                NaN                  NaN
# 4016                                                NaN                  NaN
# 4017                                                NaN                  NaN
# 4018                                                NaN                  NaN
# 4019                                                NaN                  NaN
# 4020                                                NaN                  NaN
# 4021                                                NaN                  NaN
# 4022                                                NaN                  NaN
# 4023                                                NaN                  NaN
# 4024                                                NaN                  NaN
# 4025                                                NaN                  NaN
# 4026                                                NaN                  NaN
# 4027                                                NaN                  NaN
# 4028                                                NaN                  NaN
# 4029                                                NaN                  NaN
# 4030                                                NaN                  NaN
# 4031                                                NaN                  NaN
# 4032                                                NaN                  NaN
# 4033                                                NaN                  NaN
# 4034                                                NaN                  NaN
# 4035                                                NaN                  NaN
# 4036                                                NaN                  NaN
# 4037                                                NaN                  NaN
# 4038                                                NaN                  NaN
# 4039                                                NaN                  NaN
#
#      faction durability  card_id_dust             action cost_dust
# 0        NaN        NaN     BRM_010t2    CRAFTING_NORMAL        40
# 1        NaN        NaN     BRM_010t2    CRAFTING_GOLDEN       400
# 2        NaN        NaN     BRM_010t2  DISENCHANT_NORMAL         5
# 3        NaN        NaN     BRM_010t2  DISENCHANT_GOLDEN        50
# 4        NaN        NaN        AT_132    CRAFTING_NORMAL      1600
# 5        NaN        NaN        AT_132    CRAFTING_GOLDEN      3200
# 6        NaN        NaN        AT_132  DISENCHANT_NORMAL       400
# 7        NaN        NaN        AT_132  DISENCHANT_GOLDEN      1600
# 8        NaN        NaN        OG_141    CRAFTING_NORMAL        40
# 9        NaN        NaN        OG_141    CRAFTING_GOLDEN       400
# 10       NaN        NaN        OG_141  DISENCHANT_NORMAL         5
# 11       NaN        NaN        OG_141  DISENCHANT_GOLDEN        50
# 12       NaN        NaN        AT_131    CRAFTING_NORMAL      1600
# 13       NaN        NaN        AT_131    CRAFTING_GOLDEN      3200
# 14       NaN        NaN        AT_131  DISENCHANT_NORMAL       400
# 15       NaN        NaN        AT_131  DISENCHANT_GOLDEN      1600
# 16       NaN        NaN       EX1_583    CRAFTING_NORMAL        40
# 17       NaN        NaN       EX1_583    CRAFTING_GOLDEN       400
# 18       NaN        NaN       EX1_583  DISENCHANT_NORMAL         5
# 19       NaN        NaN       EX1_583  DISENCHANT_GOLDEN        50
# 20       NaN        NaN       CFM_095    CRAFTING_NORMAL       400
# 21       NaN        NaN       CFM_095    CRAFTING_GOLDEN      1600
# 22       NaN        NaN       CFM_095  DISENCHANT_NORMAL       100
# 23       NaN        NaN       CFM_095  DISENCHANT_GOLDEN       400
# 24       NaN        NaN       BRM_018    CRAFTING_NORMAL       100
# 25       NaN        NaN       BRM_018    CRAFTING_GOLDEN       800
# 26       NaN        NaN       BRM_018  DISENCHANT_NORMAL        20
# 27       NaN        NaN       BRM_018  DISENCHANT_GOLDEN       100
# 28     HORDE        NaN        OG_027    CRAFTING_NORMAL       100
# 29       NaN        NaN        OG_027    CRAFTING_GOLDEN       800
# ...      ...        ...           ...                ...       ...
# 4010     NaN        NaN       tt_010a  DISENCHANT_NORMAL       100
# 4011     NaN        NaN       tt_010a  DISENCHANT_GOLDEN       400
# 4012     NaN        NaN       EX1_559    CRAFTING_NORMAL      1600
# 4013     NaN        NaN       EX1_559    CRAFTING_GOLDEN      3200
# 4014     NaN        NaN       EX1_559  DISENCHANT_NORMAL       400
# 4015     NaN        NaN       EX1_559  DISENCHANT_GOLDEN      1600
# 4016     NaN        NaN       EX1_624    CRAFTING_NORMAL       100
# 4017     NaN        NaN       EX1_624    CRAFTING_GOLDEN       800
# 4018     NaN        NaN       EX1_624  DISENCHANT_NORMAL        20
# 4019     NaN        NaN       EX1_624  DISENCHANT_GOLDEN       100
# 4020     NaN        NaN       OG_044a    CRAFTING_NORMAL        40
# 4021     NaN        NaN       OG_044a    CRAFTING_GOLDEN       400
# 4022     NaN        NaN       OG_044a  DISENCHANT_NORMAL         5
# 4023     NaN        NaN       OG_044a  DISENCHANT_GOLDEN        50
# 4024     NaN        NaN        AT_044    CRAFTING_NORMAL       400
# 4025     NaN        NaN        AT_044    CRAFTING_GOLDEN      1600
# 4026     NaN        NaN        AT_044  DISENCHANT_NORMAL       100
# 4027     NaN        NaN        AT_044  DISENCHANT_GOLDEN       400
# 4028     NaN        NaN      EX1_345t    CRAFTING_NORMAL       400
# 4029     NaN        NaN      EX1_345t    CRAFTING_GOLDEN      1600
# 4030     NaN        NaN      EX1_345t  DISENCHANT_NORMAL       100
# 4031     NaN        NaN      EX1_345t  DISENCHANT_GOLDEN       400
# 4032     NaN        NaN       EX1_009    CRAFTING_NORMAL       100
# 4033     NaN        NaN       EX1_009    CRAFTING_GOLDEN       800
# 4034     NaN        NaN       EX1_009  DISENCHANT_NORMAL        20
# 4035     NaN        NaN       EX1_009  DISENCHANT_GOLDEN       100
# 4036     NaN        NaN       CS2_031    CRAFTING_NORMAL        40
# 4037     NaN        NaN       CS2_031    CRAFTING_GOLDEN       400
# 4038     NaN        NaN       CS2_031  DISENCHANT_NORMAL         5
# 4039     NaN        NaN       CS2_031  DISENCHANT_GOLDEN        50
#
# [4040 rows x 21 columns]

# %% [markdown]
# Inspect the output above.  Note that the naming collision has been avoided by renaming the `cost` column from the right table to `cost_dust`.
#
# ## Summary
#
# In this lab, you learned how to:
#
# * Concatenate multiple DataFrames together into a single DataFrame
# * Understand and execute the various types of joins (inner, outer, left, and right joins)
